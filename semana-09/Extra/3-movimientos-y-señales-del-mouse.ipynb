# %% [markdown]
# <font size='1'>Material elaborado en 2017-2 por Hugo Navarrete e Ignacio Acevedo.</font>

# %% [markdown]
# # Movimientos y señales del mouse
#
# Dentro de una interfaz podríamos necesitar utilizar la posición del mouse o realizar cierta acción al momento de hacer un click (como dispararle a alienígenas intergalácticos). Para nuestro beneficio, PyQt5 tiene integradas varias funcionalidades para poder utilizar y manejar esta información.

# %% [markdown]
# ## Movimiento
#
# En el siguiente ejemplo, vamos a ver la posición global del mouse mediante el evento `mouseMoveEvent`. Para esto, vamos a activar el _tracking_ del mouse en el `widget` y `label` que queramos seguir. En el ejemplo, solo lo activamos en el label azul; el label verde no mostrará la posición del mouse.

# %%
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QLabel)
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import QRect


class MiVentana(QWidget):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.init_GUI()

    def init_GUI(self):
        self.setGeometry(300, 100, 225, 450)
        self.setMaximumHeight(450)
        self.setMaximumWidth(225)
        self.setWindowTitle('Tracking')
        
        # Creamos el label
        self.blue_label = QLabel('AZUL', self)
        self.blue_label.move(0, 0)
        self.blue_label.setGeometry(QRect(0, 0, 225, 225))  # (x, y, height, width)
        
        self.green_label = QLabel('VERDE', self)
        self.green_label.move(0, 0)
        self.green_label.setGeometry(QRect(0, 225, 225, 225))
        
        self.pixmap_azul = QPixmap('images/colors/azul.png') # Creamos el pixmap
        self.pixmap_verde = QPixmap('images/colors/verde.png')
        
        self.blue_label.setPixmap(self.pixmap_azul) # Asignamos el pixmap
        self.green_label.setPixmap(self.pixmap_verde)
        
        self.setMouseTracking(True) # Activamos el tracking en nuestra ventana y nuestra label azul
        self.blue_label.setMouseTracking(True)
        self.blue_label.show()
        self.green_label.show()
        self.show()

    def mouseMoveEvent(self, event):
        print(event.pos()) 


if __name__ == '__main__':
    app = QApplication([])
    form = MiVentana()
    sys.exit(app.exec_())
# Out:
# PyQt5.QtCore.QPoint(223, 196)
# PyQt5.QtCore.QPoint(202, 191)
# PyQt5.QtCore.QPoint(201, 191)
# PyQt5.QtCore.QPoint(197, 190)
# PyQt5.QtCore.QPoint(193, 189)
# PyQt5.QtCore.QPoint(191, 189)
# PyQt5.QtCore.QPoint(188, 188)
# PyQt5.QtCore.QPoint(185, 187)
# PyQt5.QtCore.QPoint(182, 187)
# PyQt5.QtCore.QPoint(178, 187)
# PyQt5.QtCore.QPoint(174, 186)
# PyQt5.QtCore.QPoint(173, 185)
# PyQt5.QtCore.QPoint(171, 185)
# PyQt5.QtCore.QPoint(169, 185)
# PyQt5.QtCore.QPoint(166, 184)
# PyQt5.QtCore.QPoint(164, 184)
# PyQt5.QtCore.QPoint(162, 183)
# PyQt5.QtCore.QPoint(160, 182)
# PyQt5.QtCore.QPoint(158, 181)
# PyQt5.QtCore.QPoint(157, 181)
# PyQt5.QtCore.QPoint(156, 180)
# PyQt5.QtCore.QPoint(154, 179)
# PyQt5.QtCore.QPoint(152, 178)
# PyQt5.QtCore.QPoint(151, 177)
# PyQt5.QtCore.QPoint(150, 176)
# PyQt5.QtCore.QPoint(149, 176)
# PyQt5.QtCore.QPoint(148, 175)
# PyQt5.QtCore.QPoint(147, 175)
# PyQt5.QtCore.QPoint(146, 174)
# PyQt5.QtCore.QPoint(145, 173)
# PyQt5.QtCore.QPoint(145, 173)
# PyQt5.QtCore.QPoint(144, 172)
# PyQt5.QtCore.QPoint(144, 171)
# PyQt5.QtCore.QPoint(143, 171)
# PyQt5.QtCore.QPoint(142, 170)
# PyQt5.QtCore.QPoint(141, 169)
# PyQt5.QtCore.QPoint(141, 169)
# PyQt5.QtCore.QPoint(140, 168)
# PyQt5.QtCore.QPoint(139, 168)
# PyQt5.QtCore.QPoint(139, 168)
# PyQt5.QtCore.QPoint(138, 168)
# PyQt5.QtCore.QPoint(138, 168)
# PyQt5.QtCore.QPoint(138, 168)
# PyQt5.QtCore.QPoint(137, 167)
# PyQt5.QtCore.QPoint(137, 168)
# PyQt5.QtCore.QPoint(137, 169)
# PyQt5.QtCore.QPoint(137, 170)
# PyQt5.QtCore.QPoint(137, 171)
# PyQt5.QtCore.QPoint(137, 172)
# PyQt5.QtCore.QPoint(137, 172)
# PyQt5.QtCore.QPoint(137, 173)
# PyQt5.QtCore.QPoint(137, 174)
# PyQt5.QtCore.QPoint(137, 175)
# PyQt5.QtCore.QPoint(137, 176)
# PyQt5.QtCore.QPoint(137, 177)
# PyQt5.QtCore.QPoint(137, 177)
# PyQt5.QtCore.QPoint(137, 180)
# PyQt5.QtCore.QPoint(136, 181)
# PyQt5.QtCore.QPoint(136, 184)
# PyQt5.QtCore.QPoint(136, 186)
# PyQt5.QtCore.QPoint(134, 190)
# PyQt5.QtCore.QPoint(134, 192)
# PyQt5.QtCore.QPoint(133, 196)
# PyQt5.QtCore.QPoint(133, 198)
# PyQt5.QtCore.QPoint(133, 202)
# PyQt5.QtCore.QPoint(132, 204)
# PyQt5.QtCore.QPoint(132, 208)
# PyQt5.QtCore.QPoint(132, 210)
# PyQt5.QtCore.QPoint(132, 212)
# PyQt5.QtCore.QPoint(132, 214)
# PyQt5.QtCore.QPoint(132, 215)
# PyQt5.QtCore.QPoint(131, 218)
# PyQt5.QtCore.QPoint(131, 220)
# PyQt5.QtCore.QPoint(131, 222)
# PyQt5.QtCore.QPoint(131, 224)
# PyQt5.QtCore.QPoint(168, 220)
# PyQt5.QtCore.QPoint(165, 215)
# PyQt5.QtCore.QPoint(162, 211)
# PyQt5.QtCore.QPoint(160, 208)
# PyQt5.QtCore.QPoint(157, 204)
# PyQt5.QtCore.QPoint(155, 200)
# PyQt5.QtCore.QPoint(152, 198)
# PyQt5.QtCore.QPoint(150, 193)
# PyQt5.QtCore.QPoint(147, 189)
# PyQt5.QtCore.QPoint(144, 185)
# PyQt5.QtCore.QPoint(141, 182)
# PyQt5.QtCore.QPoint(138, 177)
# PyQt5.QtCore.QPoint(135, 173)
# PyQt5.QtCore.QPoint(132, 170)
# PyQt5.QtCore.QPoint(130, 166)
# PyQt5.QtCore.QPoint(128, 163)
# PyQt5.QtCore.QPoint(124, 158)
# PyQt5.QtCore.QPoint(124, 156)
# PyQt5.QtCore.QPoint(121, 154)
# PyQt5.QtCore.QPoint(120, 151)
# PyQt5.QtCore.QPoint(118, 148)
# PyQt5.QtCore.QPoint(117, 147)
# PyQt5.QtCore.QPoint(115, 145)
# PyQt5.QtCore.QPoint(114, 143)
# PyQt5.QtCore.QPoint(113, 140)
# PyQt5.QtCore.QPoint(112, 139)
# PyQt5.QtCore.QPoint(111, 137)
# PyQt5.QtCore.QPoint(109, 135)
# PyQt5.QtCore.QPoint(108, 133)
# PyQt5.QtCore.QPoint(108, 131)
# PyQt5.QtCore.QPoint(107, 130)
# PyQt5.QtCore.QPoint(106, 129)
# PyQt5.QtCore.QPoint(106, 128)
# PyQt5.QtCore.QPoint(104, 127)
# PyQt5.QtCore.QPoint(104, 126)
# PyQt5.QtCore.QPoint(103, 125)
# PyQt5.QtCore.QPoint(103, 124)
# PyQt5.QtCore.QPoint(102, 123)
# PyQt5.QtCore.QPoint(101, 121)
# PyQt5.QtCore.QPoint(101, 120)
# PyQt5.QtCore.QPoint(100, 119)
# PyQt5.QtCore.QPoint(100, 119)
# PyQt5.QtCore.QPoint(100, 118)
# PyQt5.QtCore.QPoint(100, 117)
# PyQt5.QtCore.QPoint(99, 116)
# PyQt5.QtCore.QPoint(99, 115)
# PyQt5.QtCore.QPoint(99, 115)
# PyQt5.QtCore.QPoint(98, 114)
# PyQt5.QtCore.QPoint(98, 113)
# PyQt5.QtCore.QPoint(98, 113)
# PyQt5.QtCore.QPoint(97, 112)
# PyQt5.QtCore.QPoint(97, 112)
# PyQt5.QtCore.QPoint(97, 112)
# PyQt5.QtCore.QPoint(97, 112)
# PyQt5.QtCore.QPoint(96, 112)
# PyQt5.QtCore.QPoint(96, 112)
# PyQt5.QtCore.QPoint(96, 111)
# PyQt5.QtCore.QPoint(96, 111)
# PyQt5.QtCore.QPoint(96, 111)
# PyQt5.QtCore.QPoint(95, 111)
# PyQt5.QtCore.QPoint(95, 111)
# PyQt5.QtCore.QPoint(95, 112)
# PyQt5.QtCore.QPoint(95, 112)
# PyQt5.QtCore.QPoint(95, 112)
# PyQt5.QtCore.QPoint(95, 113)
# PyQt5.QtCore.QPoint(95, 114)
# PyQt5.QtCore.QPoint(95, 115)
# PyQt5.QtCore.QPoint(95, 116)
# PyQt5.QtCore.QPoint(95, 117)
# PyQt5.QtCore.QPoint(95, 119)
# PyQt5.QtCore.QPoint(95, 121)
# PyQt5.QtCore.QPoint(95, 122)
# PyQt5.QtCore.QPoint(96, 124)
# PyQt5.QtCore.QPoint(96, 128)
# PyQt5.QtCore.QPoint(97, 129)
# PyQt5.QtCore.QPoint(98, 135)
# PyQt5.QtCore.QPoint(99, 139)
# PyQt5.QtCore.QPoint(101, 143)
# PyQt5.QtCore.QPoint(102, 146)
# PyQt5.QtCore.QPoint(105, 154)
# PyQt5.QtCore.QPoint(107, 160)
# PyQt5.QtCore.QPoint(109, 165)
# PyQt5.QtCore.QPoint(111, 171)
# PyQt5.QtCore.QPoint(114, 176)
# PyQt5.QtCore.QPoint(116, 181)
# PyQt5.QtCore.QPoint(119, 186)
# PyQt5.QtCore.QPoint(124, 191)
# PyQt5.QtCore.QPoint(129, 195)
# PyQt5.QtCore.QPoint(135, 200)
# PyQt5.QtCore.QPoint(147, 208)
# PyQt5.QtCore.QPoint(151, 210)
# PyQt5.QtCore.QPoint(161, 215)
# PyQt5.QtCore.QPoint(174, 224)
# PyQt5.QtCore.QPoint(225, 353)
# PyQt5.QtCore.QPoint(215, 83)
# PyQt5.QtCore.QPoint(199, 72)
# PyQt5.QtCore.QPoint(183, 62)
# PyQt5.QtCore.QPoint(177, 58)
# PyQt5.QtCore.QPoint(163, 50)
# PyQt5.QtCore.QPoint(151, 41)
# PyQt5.QtCore.QPoint(142, 36)
# PyQt5.QtCore.QPoint(133, 31)
# PyQt5.QtCore.QPoint(130, 30)
# PyQt5.QtCore.QPoint(123, 28)
# PyQt5.QtCore.QPoint(114, 24)
# PyQt5.QtCore.QPoint(108, 22)
# PyQt5.QtCore.QPoint(107, 21)
# PyQt5.QtCore.QPoint(98, 19)
# PyQt5.QtCore.QPoint(95, 19)
# PyQt5.QtCore.QPoint(91, 19)
# PyQt5.QtCore.QPoint(82, 18)
# PyQt5.QtCore.QPoint(79, 16)
# PyQt5.QtCore.QPoint(76, 16)
# PyQt5.QtCore.QPoint(69, 15)
# PyQt5.QtCore.QPoint(67, 14)
# PyQt5.QtCore.QPoint(63, 13)
# PyQt5.QtCore.QPoint(59, 13)
# PyQt5.QtCore.QPoint(54, 12)
# PyQt5.QtCore.QPoint(53, 11)
# PyQt5.QtCore.QPoint(50, 11)
# PyQt5.QtCore.QPoint(48, 11)
# PyQt5.QtCore.QPoint(45, 11)
# PyQt5.QtCore.QPoint(44, 11)
# PyQt5.QtCore.QPoint(43, 11)
# PyQt5.QtCore.QPoint(41, 11)
# PyQt5.QtCore.QPoint(40, 11)
# PyQt5.QtCore.QPoint(39, 11)
# PyQt5.QtCore.QPoint(39, 11)
# PyQt5.QtCore.QPoint(39, 11)
# PyQt5.QtCore.QPoint(38, 11)
# PyQt5.QtCore.QPoint(38, 11)
# PyQt5.QtCore.QPoint(37, 11)
# PyQt5.QtCore.QPoint(37, 12)
# PyQt5.QtCore.QPoint(36, 13)
# PyQt5.QtCore.QPoint(36, 14)
# PyQt5.QtCore.QPoint(35, 16)
# PyQt5.QtCore.QPoint(35, 18)
# PyQt5.QtCore.QPoint(34, 20)
# PyQt5.QtCore.QPoint(34, 22)
# PyQt5.QtCore.QPoint(34, 25)
# PyQt5.QtCore.QPoint(34, 27)
# PyQt5.QtCore.QPoint(34, 31)
# PyQt5.QtCore.QPoint(34, 33)
# PyQt5.QtCore.QPoint(34, 36)
# PyQt5.QtCore.QPoint(34, 37)
# PyQt5.QtCore.QPoint(34, 40)
# PyQt5.QtCore.QPoint(34, 41)
# PyQt5.QtCore.QPoint(34, 42)
# PyQt5.QtCore.QPoint(34, 43)
# PyQt5.QtCore.QPoint(34, 44)
# PyQt5.QtCore.QPoint(34, 45)
# PyQt5.QtCore.QPoint(35, 46)
# PyQt5.QtCore.QPoint(35, 47)
# PyQt5.QtCore.QPoint(36, 48)
# PyQt5.QtCore.QPoint(36, 49)
# PyQt5.QtCore.QPoint(37, 50)
# PyQt5.QtCore.QPoint(38, 50)
# PyQt5.QtCore.QPoint(38, 51)
# PyQt5.QtCore.QPoint(39, 52)
# PyQt5.QtCore.QPoint(39, 52)
# PyQt5.QtCore.QPoint(40, 53)
# PyQt5.QtCore.QPoint(41, 53)
# PyQt5.QtCore.QPoint(42, 54)
# PyQt5.QtCore.QPoint(42, 54)
# PyQt5.QtCore.QPoint(43, 55)
# PyQt5.QtCore.QPoint(44, 55)
# PyQt5.QtCore.QPoint(45, 55)
# PyQt5.QtCore.QPoint(46, 56)
# PyQt5.QtCore.QPoint(48, 56)
# PyQt5.QtCore.QPoint(49, 57)
# PyQt5.QtCore.QPoint(50, 57)
# PyQt5.QtCore.QPoint(51, 58)
# PyQt5.QtCore.QPoint(53, 58)
# PyQt5.QtCore.QPoint(55, 60)
# PyQt5.QtCore.QPoint(56, 60)
# PyQt5.QtCore.QPoint(60, 62)
# PyQt5.QtCore.QPoint(62, 63)
# PyQt5.QtCore.QPoint(65, 66)
# PyQt5.QtCore.QPoint(69, 67)
# PyQt5.QtCore.QPoint(72, 69)
# PyQt5.QtCore.QPoint(74, 70)
# PyQt5.QtCore.QPoint(76, 71)
# PyQt5.QtCore.QPoint(79, 73)
# PyQt5.QtCore.QPoint(81, 74)
# PyQt5.QtCore.QPoint(82, 75)
# PyQt5.QtCore.QPoint(84, 76)
# PyQt5.QtCore.QPoint(85, 77)
# PyQt5.QtCore.QPoint(85, 78)
# PyQt5.QtCore.QPoint(86, 78)
# PyQt5.QtCore.QPoint(87, 79)
# PyQt5.QtCore.QPoint(88, 80)
# PyQt5.QtCore.QPoint(88, 81)
# PyQt5.QtCore.QPoint(89, 83)
# PyQt5.QtCore.QPoint(90, 84)
# PyQt5.QtCore.QPoint(91, 85)
# PyQt5.QtCore.QPoint(92, 86)
# PyQt5.QtCore.QPoint(94, 88)
# PyQt5.QtCore.QPoint(95, 90)
# PyQt5.QtCore.QPoint(96, 93)
# PyQt5.QtCore.QPoint(97, 94)
# PyQt5.QtCore.QPoint(98, 95)
# PyQt5.QtCore.QPoint(99, 97)
# PyQt5.QtCore.QPoint(100, 98)
# PyQt5.QtCore.QPoint(100, 100)
# PyQt5.QtCore.QPoint(101, 100)
# PyQt5.QtCore.QPoint(102, 102)
# PyQt5.QtCore.QPoint(103, 103)
# PyQt5.QtCore.QPoint(103, 105)
# PyQt5.QtCore.QPoint(105, 106)
# PyQt5.QtCore.QPoint(105, 108)
# PyQt5.QtCore.QPoint(106, 110)
# PyQt5.QtCore.QPoint(106, 112)
# PyQt5.QtCore.QPoint(107, 113)
# PyQt5.QtCore.QPoint(107, 114)
# PyQt5.QtCore.QPoint(108, 115)
# PyQt5.QtCore.QPoint(108, 116)
# PyQt5.QtCore.QPoint(108, 117)
# PyQt5.QtCore.QPoint(109, 118)
# PyQt5.QtCore.QPoint(109, 119)
# PyQt5.QtCore.QPoint(109, 120)
# PyQt5.QtCore.QPoint(110, 120)
# PyQt5.QtCore.QPoint(110, 121)
# PyQt5.QtCore.QPoint(110, 122)
# PyQt5.QtCore.QPoint(110, 122)
# PyQt5.QtCore.QPoint(111, 123)
# PyQt5.QtCore.QPoint(111, 123)
# PyQt5.QtCore.QPoint(111, 124)
# PyQt5.QtCore.QPoint(111, 124)
# PyQt5.QtCore.QPoint(112, 124)
# PyQt5.QtCore.QPoint(112, 125)
# PyQt5.QtCore.QPoint(112, 125)
# PyQt5.QtCore.QPoint(112, 126)
# PyQt5.QtCore.QPoint(112, 126)
# PyQt5.QtCore.QPoint(112, 127)
# PyQt5.QtCore.QPoint(113, 127)
# PyQt5.QtCore.QPoint(113, 127)
# PyQt5.QtCore.QPoint(113, 127)
# PyQt5.QtCore.QPoint(113, 127)
# PyQt5.QtCore.QPoint(113, 128)
# PyQt5.QtCore.QPoint(113, 128)
# PyQt5.QtCore.QPoint(113, 129)
# PyQt5.QtCore.QPoint(113, 129)
# PyQt5.QtCore.QPoint(113, 129)
# PyQt5.QtCore.QPoint(113, 130)
# PyQt5.QtCore.QPoint(113, 130)
# PyQt5.QtCore.QPoint(113, 131)
# PyQt5.QtCore.QPoint(113, 131)
# PyQt5.QtCore.QPoint(114, 132)
# PyQt5.QtCore.QPoint(114, 132)
# PyQt5.QtCore.QPoint(114, 133)
# PyQt5.QtCore.QPoint(114, 133)
# PyQt5.QtCore.QPoint(114, 134)
# PyQt5.QtCore.QPoint(114, 134)
# PyQt5.QtCore.QPoint(114, 135)
# PyQt5.QtCore.QPoint(114, 135)
# PyQt5.QtCore.QPoint(114, 136)
# PyQt5.QtCore.QPoint(114, 136)
# PyQt5.QtCore.QPoint(114, 136)
# PyQt5.QtCore.QPoint(114, 137)
# PyQt5.QtCore.QPoint(115, 137)
# PyQt5.QtCore.QPoint(115, 138)
# PyQt5.QtCore.QPoint(115, 138)
# PyQt5.QtCore.QPoint(115, 138)
# PyQt5.QtCore.QPoint(115, 139)
# PyQt5.QtCore.QPoint(115, 140)
# PyQt5.QtCore.QPoint(115, 140)
# PyQt5.QtCore.QPoint(115, 141)
# PyQt5.QtCore.QPoint(115, 142)
# PyQt5.QtCore.QPoint(115, 143)
# PyQt5.QtCore.QPoint(115, 144)
# PyQt5.QtCore.QPoint(115, 146)
# PyQt5.QtCore.QPoint(115, 148)
# PyQt5.QtCore.QPoint(116, 151)
# PyQt5.QtCore.QPoint(116, 156)
# PyQt5.QtCore.QPoint(116, 158)
# PyQt5.QtCore.QPoint(117, 167)
# PyQt5.QtCore.QPoint(118, 170)
# PyQt5.QtCore.QPoint(119, 182)
# PyQt5.QtCore.QPoint(120, 191)
# PyQt5.QtCore.QPoint(121, 202)
# PyQt5.QtCore.QPoint(121, 214)
# PyQt5.QtCore.QPoint(141, 223)
# PyQt5.QtCore.QPoint(139, 214)
# PyQt5.QtCore.QPoint(139, 210)
# PyQt5.QtCore.QPoint(137, 204)
# PyQt5.QtCore.QPoint(135, 198)
# PyQt5.QtCore.QPoint(135, 194)
# PyQt5.QtCore.QPoint(134, 191)
# PyQt5.QtCore.QPoint(133, 188)
# PyQt5.QtCore.QPoint(133, 187)
# PyQt5.QtCore.QPoint(133, 186)
# PyQt5.QtCore.QPoint(133, 185)
# PyQt5.QtCore.QPoint(133, 184)
# PyQt5.QtCore.QPoint(133, 183)
# PyQt5.QtCore.QPoint(133, 182)
# PyQt5.QtCore.QPoint(132, 181)
# PyQt5.QtCore.QPoint(132, 180)
# PyQt5.QtCore.QPoint(132, 179)
# PyQt5.QtCore.QPoint(132, 179)
# PyQt5.QtCore.QPoint(132, 177)
# PyQt5.QtCore.QPoint(132, 176)
# PyQt5.QtCore.QPoint(132, 175)
# PyQt5.QtCore.QPoint(132, 173)
# PyQt5.QtCore.QPoint(132, 171)
# PyQt5.QtCore.QPoint(131, 169)
# PyQt5.QtCore.QPoint(131, 166)
# PyQt5.QtCore.QPoint(131, 164)
# PyQt5.QtCore.QPoint(131, 161)
# PyQt5.QtCore.QPoint(130, 159)
# PyQt5.QtCore.QPoint(130, 157)
# PyQt5.QtCore.QPoint(130, 155)
# PyQt5.QtCore.QPoint(130, 154)
# PyQt5.QtCore.QPoint(130, 152)
# PyQt5.QtCore.QPoint(130, 151)
# PyQt5.QtCore.QPoint(130, 150)
# PyQt5.QtCore.QPoint(130, 150)
# PyQt5.QtCore.QPoint(130, 149)
# PyQt5.QtCore.QPoint(130, 149)
# PyQt5.QtCore.QPoint(130, 148)
# PyQt5.QtCore.QPoint(130, 148)
# PyQt5.QtCore.QPoint(130, 147)
# PyQt5.QtCore.QPoint(130, 147)
# PyQt5.QtCore.QPoint(130, 147)
# PyQt5.QtCore.QPoint(130, 146)
# PyQt5.QtCore.QPoint(130, 145)
# PyQt5.QtCore.QPoint(130, 145)
# PyQt5.QtCore.QPoint(129, 144)
# PyQt5.QtCore.QPoint(129, 143)
# PyQt5.QtCore.QPoint(129, 143)
# PyQt5.QtCore.QPoint(129, 142)
# PyQt5.QtCore.QPoint(129, 142)
# PyQt5.QtCore.QPoint(129, 142)
# PyQt5.QtCore.QPoint(129, 141)
# PyQt5.QtCore.QPoint(129, 141)
# PyQt5.QtCore.QPoint(129, 140)
# PyQt5.QtCore.QPoint(129, 140)
# PyQt5.QtCore.QPoint(129, 139)
# PyQt5.QtCore.QPoint(129, 139)
# PyQt5.QtCore.QPoint(129, 139)
# PyQt5.QtCore.QPoint(129, 139)
# PyQt5.QtCore.QPoint(131, 139)
# PyQt5.QtCore.QPoint(134, 140)
# PyQt5.QtCore.QPoint(136, 141)
# PyQt5.QtCore.QPoint(141, 143)
# PyQt5.QtCore.QPoint(146, 147)
# PyQt5.QtCore.QPoint(152, 149)
# PyQt5.QtCore.QPoint(163, 156)
# PyQt5.QtCore.QPoint(167, 158)
# PyQt5.QtCore.QPoint(175, 162)
# PyQt5.QtCore.QPoint(184, 167)
# PyQt5.QtCore.QPoint(201, 175)
# PyQt5.QtCore.QPoint(206, 177)
# PyQt5.QtCore.QPoint(223, 186)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Press Event
#
# En este ejemplo vamos a ocupar el evento `mousePressEvent`, el cual se activa al presionar un click. Los _labels_ se ocultarán cuando se haga _click_ en ellos y se mostrarán cuando se haga _click_ en la posición en la que estaban.

# %%
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QPushButton, QLabel)
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import QRect


class MiVentana(QWidget):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.init_GUI()

    def init_GUI(self):
        self.setGeometry(300, 100, 225, 450)
        self.setMaximumHeight(450)
        self.setMaximumWidth(225)
        self.setWindowTitle('Move Event')
        
        self.blue_hide = True
        self.blue_label = QLabel('AZUL', self)
        self.blue_label.move(0, 0)
        self.blue_label.setGeometry(QRect(0, 0, 225, 225))  # (x, y, height, width)
        self.pixmap_azul = QPixmap('images/colors/azul.png')
        self.blue_label.setPixmap(self.pixmap_azul)
        self.blue_label.show()
        
        self.green_hide = True
        self.green_label = QLabel('VERDE', self)
        self.green_label.move(0, 0)
        self.green_label.setGeometry(QRect(0, 225, 225, 225))
        self.pixmap_verde = QPixmap('images/colors/verde.png')  
        self.green_label.setPixmap(self.pixmap_verde)       
        self.green_label.show()
        
        self.show()

    def mousePressEvent(self, event):
        if event.y() <= 225: # Este es el alto del label
            if self.blue_hide:
                self.blue_label.hide()
            else:
                self.blue_label.show()
            self.blue_hide = not self.blue_hide
        else:
            if self.green_hide:
                self.green_label.hide()
            else:
                self.green_label.show()
            self.green_hide = not self.green_hide


if __name__ == '__main__':
    app = QApplication([])
    form = MiVentana()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
